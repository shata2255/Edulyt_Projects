# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Credit card transactions - Project - 2 - Credit card transactions - Project - 2.csv")

# %%
df.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India  05-May-15       Gold    Bills      F  171574

# %% [markdown]
# # 1.Print top 5 cities with highest spends and their percentage contribution of total credit card spends.

# %%
z=df.groupby(["City"])["Amount"].sum().nlargest(5)

# %%
p=z.reset_index()

# %%
p
# Out:
#                     City     Amount
# 0  Greater Mumbai, India  576751476
# 1       Bengaluru, India  572326739
# 2       Ahmedabad, India  567794310
# 3           Delhi, India  556929212
# 4         Kolkata, India  115466943

# %%
p["per"]=((p["Amount"]*100)/(p["Amount"].sum()))

# %%
p
# Out:
#                     City     Amount        per
# 0  Greater Mumbai, India  576751476  24.139247
# 1       Bengaluru, India  572326739  23.954055
# 2       Ahmedabad, India  567794310  23.764356
# 3           Delhi, India  556929212  23.309610
# 4         Kolkata, India  115466943   4.832732

# %% [markdown]
# # 2.Print highest spend month and amount spent in that month for each card type.

# %%
df.head(3)
# Out:
#    index                   City       Date Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14      Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14  Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14    Silver    Bills      F  101738

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df["Month"]=df["Date"].dt.month

# %%
df["Year"]=df["Date"].dt.year

# %%
df.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2      2       Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4      4       Bengaluru, India 2015-05-05       Gold    Bills      F  171574
#
#    Month  Year
# 0     10  2014
# 1      8  2014
# 2      8  2014
# 3      4  2014
# 4      5  2015

# %%
d={1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"Jun",7:"Jul",8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"}

# %%
df["Month"]=df["Month"].map(d)

# %%
df.head(2)
# Out:
#    index                   City       Date Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India 2014-10-29      Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22  Platinum    Bills      F   32555
#
#   Month  Year
# 0   Oct  2014
# 1   Aug  2014

# %%
g=df[df["Card Type"]=="Gold"]

# %%
go=g.groupby(["Card Type","Month","Year"])["Amount"].sum().nlargest(1)

# %%
gg=go.reset_index()

# %%
gg
# Out:
#   Card Type Month  Year    Amount
# 0      Gold   Jan  2015  55455064

# %%
s=df[df["Card Type"]=="Silver"]

# %%
si=s.groupby(["Card Type","Month","Year"])["Amount"].sum().nlargest(1)

# %%
ss=si.reset_index()

# %%
ss
# Out:
#   Card Type Month  Year    Amount
# 0    Silver   Mar  2015  59723549

# %%
p=df[df["Card Type"]=="Platinum"]

# %%
pl=p.groupby(["Card Type","Month","Year"])["Amount"].sum().nlargest(1)

# %%
pp=pl.reset_index()

# %%
pp
# Out:
#   Card Type Month  Year    Amount
# 0  Platinum   Aug  2014  57936507

# %%
sig=df[df["Card Type"]=="Signature"]

# %%
sigg=sig.groupby(["Card Type","Month","Year"])["Amount"].sum().nlargest(1)

# %%
sss=sigg.reset_index()

# %%
sss
# Out:
#    Card Type Month  Year    Amount
# 0  Signature   Dec  2013  58799522

# %%
c=pd.concat([gg,ss,pp,sss],axis=0)

# %%
c
# Out:
#    Card Type Month  Year    Amount
# 0       Gold   Jan  2015  55455064
# 0     Silver   Mar  2015  59723549
# 0   Platinum   Aug  2014  57936507
# 0  Signature   Dec  2013  58799522

# %% [markdown]
# # 4.Find city which had lowest percentage spend for gold card type.

# %%
g=df[df["Card Type"]=="Gold"]

# %%
gg=g.reset_index()

# %%
gg.head()
# Out:
#    level_0  index                   City       Date Card Type Exp Type Gender  \
# 0        0      0           Delhi, India 2014-10-29      Gold    Bills      F
# 1        4      4       Bengaluru, India 2015-05-05      Gold    Bills      F
# 2        6      6           Delhi, India 2015-02-24      Gold    Bills      F
# 3       12     12  Greater Mumbai, India 2014-08-07      Gold    Bills      F
# 4       17     17  Greater Mumbai, India 2015-03-30      Gold    Bills      F
#
#    Amount Month  Year
# 0   82475   Oct  2014
# 1  171574   May  2015
# 2  143250   Feb  2015
# 3   19226   Aug  2014
# 4  986379   Mar  2015

# %%
gg["percentage_spend"]=((gg["Amount"]*100)/(gg["Amount"].sum()))

# %%
gg.head(2)
# Out:
#    level_0  index              City       Date Card Type Exp Type Gender  \
# 0        0      0      Delhi, India 2014-10-29      Gold    Bills      F
# 1        4      4  Bengaluru, India 2015-05-05      Gold    Bills      F
#
#    Amount Month  Year  percentage_spend
# 0   82475   Oct  2014          0.008377
# 1  171574   May  2015          0.017427

# %%
gg.nsmallest(1,"percentage_spend")
# Out:
#       level_0  index              City       Date Card Type Exp Type Gender  \
# 1251     5331   5331  Ahmedabad, India 2015-02-12      Gold     Fuel      F
#
#       Amount Month  Year  percentage_spend
# 1251    1038   Feb  2015          0.000105

# %% [markdown]
# # 5.Print 3 columns: city, highest_expense_type , lowest_expense_type (example format : Delhi , bills, Fuel).

# %%
df=pd.read_csv("Credit card transactions - Project - 2 - Credit card transactions - Project - 2.csv")

# %%
idx=df.groupby(["City"])["Amount"].idxmax()

# %%
max_scores=df.loc[idx]

# %%
max_scores.rename(columns={"Exp Type": "Highest_expense_type"},inplace=True)

# %%
max_scores
# Out:
#        index              City       Date  Card Type Highest_expense_type  \
# 17004  17004   Achalpur, India  20-Apr-15       Gold                Bills
# 14894  14894   Adilabad, India  14-Feb-15   Platinum                Bills
# 19716  19716  Adityapur, India  12-Nov-13  Signature                 Food
# 17245  17245      Adoni, India  09-Feb-14     Silver                 Fuel
# 15304  15304      Adoor, India  20-Apr-14   Platinum                 Fuel
# ...      ...               ...        ...        ...                  ...
# 16042  16042    Zaidpur, India  25-Jun-14  Signature                 Food
# 16351  16351    Zamania, India  18-Oct-14  Signature        Entertainment
# 19057  19057       Zira, India  17-Sep-14       Gold                Bills
# 17059  17059   Zirakpur, India  08-Apr-15   Platinum                 Fuel
# 18987  18987  Zunheboto, India  29-Mar-14     Silver              Grocery
#
#       Gender  Amount
# 17004      M  241504
# 14894      F  278459
# ...

# %%
df=pd.read_csv("Credit card transactions - Project - 2 - Credit card transactions - Project - 2.csv")

# %%
idr=df.groupby(["City"])["Amount"].idxmin()

# %%
min_scores=df.loc[idr]

# %%
min_scores.rename(columns={"Exp Type":"Lowest_expense_type"},inplace=True)

# %%
min_scores
# Out:
#        index              City       Date Card Type Lowest_expense_type  \
# 15604  15604   Achalpur, India  29-May-14      Gold       Entertainment
# 19457  19457   Adilabad, India  20-Feb-15      Gold             Grocery
# 14862  14862  Adityapur, India  27-Apr-14  Platinum             Grocery
# 14613  14613      Adoni, India  25-Jan-15  Platinum             Grocery
# 19860  19860      Adoor, India  22-May-14      Gold               Bills
# ...      ...               ...        ...       ...                 ...
# 14079  14079    Zaidpur, India  21-Jan-15    Silver                Food
# 15280  15280    Zamania, India  18-Jul-14    Silver       Entertainment
# 15074  15074       Zira, India  10-Jan-14  Platinum             Grocery
# 18279  18279   Zirakpur, India  08-Mar-14  Platinum       Entertainment
# 18804  18804  Zunheboto, India  01-Dec-14    Silver       Entertainment
#
#       Gender  Amount
# 15604      F   55347
# 19457      M   49020
# 14862      M   17703
# ...

# %%
p=max_scores.merge(min_scores,on="City",how="left")

# %%
e=p[["City","Highest_expense_type","Lowest_expense_type"]]

# %%
e
# Out:
#                                 City Highest_expense_type Lowest_expense_type
# 0                    Achalpur, India                Bills       Entertainment
# 1                    Adilabad, India                Bills             Grocery
# 2                   Adityapur, India                 Food             Grocery
# 3                       Adoni, India                 Fuel             Grocery
# 4                       Adoor, India                 Fuel               Bills
# 5                    Afzalpur, India                Bills                Food
# 6                    Agartala, India        Entertainment                Food
# 7                        Agra, India                Bills             Grocery
# 8                   Ahmedabad, India                Bills             Grocery
# 9                  Ahmednagar, India                 Fuel             Grocery
# 10                     Aizawl, India                 Food                Food
# ...

# %%
# !pip install openpyxl

# %%
with pd.ExcelWriter('new.xlsx') as writer:
    e.to_excel(writer, sheet_name='Task')

# %% [markdown]
# # 6. Find percentage contribution of spends by females for each expense type

# %%
df=pd.read_csv("Credit card transactions - Project - 2 - Credit card transactions - Project - 2.csv")

# %%
op=df[df["Gender"]=="F"]

# %%
op
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India  05-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26039  26039          Kanpur, India  15-Dec-14     Silver   Travel      F
# 26040  26040       Hyderabad, India  26-Oct-13       Gold   Travel      F
# 26043  26043       Hyderabad, India  15-May-15     Silver   Travel      F
# 26045  26045         Kolkata, India  26-Feb-14  Signature   Travel      F
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %%
f=op.groupby(["Exp Type","Gender"])["Amount"].sum()

# %%
ff=f.reset_index()

# %%
ff
# Out:
#         Exp Type Gender     Amount
# 0          Bills      F  580035469
# 1  Entertainment      F  358663333
# 2           Food      F  452817279
# 3           Fuel      F  392282421
# 4        Grocery      F  365646998
# 5         Travel      F   55865530

# %%
ff["Total_spend"]=sum(ff["Amount"])

# %%
ff
# Out:
#         Exp Type Gender     Amount  Total_spend
# 0          Bills      F  580035469   2205311030
# 1  Entertainment      F  358663333   2205311030
# 2           Food      F  452817279   2205311030
# 3           Fuel      F  392282421   2205311030
# 4        Grocery      F  365646998   2205311030
# 5         Travel      F   55865530   2205311030

# %%
ff["Total_percent"]=((ff["Amount"]/ff["Total_spend"])*100)

# %%
ff
# Out:
#         Exp Type Gender     Amount  Total_spend  Total_percent
# 0          Bills      F  580035469   2205311030      26.301753
# 1  Entertainment      F  358663333   2205311030      16.263617
# 2           Food      F  452817279   2205311030      20.533035
# 3           Fuel      F  392282421   2205311030      17.788077
# 4        Grocery      F  365646998   2205311030      16.580292
# 5         Travel      F   55865530   2205311030       2.533227

# %% [markdown]
# # 7.Which card and expense type combination saw highest month over month growth in Jan-2014

# %%
df
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India 2014-10-29       Gold    Bills      F
# 1          1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F
# 2          2       Bengaluru, India 2014-08-27     Silver    Bills      F
# 3          3  Greater Mumbai, India 2014-04-12  Signature    Bills      F
# 4          4       Bengaluru, India 2015-05-05       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India 2014-06-22     Silver   Travel      F
# 26048  26048            Pune, India 2014-08-03  Signature   Travel      M
# 26049  26049       Hyderabad, India 2015-01-16     Silver   Travel      M
# 26050  26050          Kanpur, India 2014-09-14     Silver   Travel      M
# 26051  26051       Hyderabad, India 2013-10-19  Signature    Bills      M
#
#        Amount Month  Year
# 0       82475   Oct  2014
# ...

# %%
e=df[(df["Month"]=="Jan")&(df["Year"]==2014)]

# %%
e
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount  \
# 36        36  Ahmedabad, India 2014-01-01  Signature    Bills      F  255577
# 65        65      Delhi, India 2014-01-23   Platinum    Bills      F  340133
# 89        89  Bengaluru, India 2014-01-05       Gold    Bills      F  327947
# 128      128      Delhi, India 2014-01-27       Gold    Bills      F  315873
# 143      143  Bengaluru, India 2014-01-03     Silver    Bills      F  297732
# ...      ...               ...        ...        ...      ...    ...     ...
# 25902  25902    Kolkata, India 2014-01-03     Silver   Travel      M   29747
# 25906  25906       Pune, India 2014-01-28     Silver   Travel      F  271663
# 25908  25908    Kolkata, India 2014-01-07       Gold   Travel      F  260837
# 25949  25949    Lucknow, India 2014-01-28   Platinum   Travel      F   57507
# 26019  26019      Surat, India 2014-01-31  Signature   Travel      M  208779
#
#       Month  Year
# 36      Jan  2014
# ...

# %%
w=e.groupby(["Card Type","Exp Type","Month","Year"])["Amount"].sum()

# %%
ww=w.reset_index()

# %%
ww["Growth_rate"]=ww["Amount"].pct_change(periods=1)*100

# %%
ww
# Out:
#     Card Type       Exp Type Month  Year    Amount  Growth_rate
# 0        Gold          Bills   Jan  2014  11137964          NaN
# 1        Gold  Entertainment   Jan  2014   9940137   -10.754452
# 2        Gold           Food   Jan  2014  11511990    15.813193
# 3        Gold           Fuel   Jan  2014  12281691     6.686081
# 4        Gold        Grocery   Jan  2014   7726804   -37.086807
# 5        Gold         Travel   Jan  2014   2092554   -72.918247
# 6    Platinum          Bills   Jan  2014  12138233   480.067850
# 7    Platinum  Entertainment   Jan  2014   9303489   -23.353844
# 8    Platinum           Food   Jan  2014  10090531     8.459643
# 9    Platinum           Fuel   Jan  2014  10698936     6.029465
# 10   Platinum        Grocery   Jan  2014  12256343    14.556653
# 11   Platinum         Travel   Jan  2014    446659   -96.355691
# 12  Signature          Bills   Jan  2014   9529821  2033.578636
# 13  Signature  Entertainment   Jan  2014   8669623    -9.026382
# ...

# %%
ww.nlargest(1,"Growth_rate")
# Out:
#     Card Type Exp Type Month  Year   Amount  Growth_rate
# 12  Signature    Bills   Jan  2014  9529821  2033.578636

# %% [markdown]
# # 8.During weekends which city has highest total spend to total no of transaction’s ratio?

# %%
df=pd.read_csv("Credit card transactions - Project - 2 - Credit card transactions - Project - 2.csv")

# %%
wkd dt.dayofweek

# %%
df.head(2)
# Out:
#    index                   City       Date Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14      Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14  Platinum    Bills      F   32555

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df["WKD"]=df["Date"].dt.dayofweek

# %%
week={0:"Mon",1:"Tue",2:"Wed",3:"Thu",4:"Fri",5:"Sat",6:"Sun"}

# %%
df["WKD"]=df["WKD"].map(week)

# %%
df.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India 2014-10-29       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India 2014-08-22   Platinum    Bills      F   32555
# 2      2       Bengaluru, India 2014-08-27     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India 2014-04-12  Signature    Bills      F  123424
# 4      4       Bengaluru, India 2015-05-05       Gold    Bills      F  171574
#
#    WKD
# 0  Wed
# 1  Fri
# 2  Wed
# 3  Sat
# 4  Tue

# %%
s=df[df["WKD"]=="Sat"]

# %%
ss=df[df["WKD"]=="Sun"]

# %%
s.shape
# Out:
# (3736, 8)

# %%
ss.shape
# Out:
# (3812, 8)

# %%
total=3736+3812

# %%
total
# Out:
# 7548

# %%
cc=pd.concat([s,ss],axis=0)

# %%
cc
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 3          3  Greater Mumbai, India 2014-04-12  Signature    Bills      F
# 11        11  Greater Mumbai, India 2013-12-07  Signature    Bills      F
# 16        16  Greater Mumbai, India 2014-06-14  Signature    Bills      F
# 18        18  Greater Mumbai, India 2014-03-15   Platinum    Bills      F
# 19        19  Greater Mumbai, India 2013-11-09   Platinum    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26030  26030         Lucknow, India 2014-07-20     Silver   Travel      M
# 26041  26041         Chennai, India 2013-12-08  Signature   Travel      M
# 26047  26047         Kolkata, India 2014-06-22     Silver   Travel      F
# 26048  26048            Pune, India 2014-08-03  Signature   Travel      M
# 26050  26050          Kanpur, India 2014-09-14     Silver   Travel      M
#
#        Amount  WKD
# 3      123424  Sat
# 11     278036  Sat
# ...

# %%
cc["total_no.of_transaction"]=total

# %%
cc
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 3          3  Greater Mumbai, India 2014-04-12  Signature    Bills      F
# 11        11  Greater Mumbai, India 2013-12-07  Signature    Bills      F
# 16        16  Greater Mumbai, India 2014-06-14  Signature    Bills      F
# 18        18  Greater Mumbai, India 2014-03-15   Platinum    Bills      F
# 19        19  Greater Mumbai, India 2013-11-09   Platinum    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26030  26030         Lucknow, India 2014-07-20     Silver   Travel      M
# 26041  26041         Chennai, India 2013-12-08  Signature   Travel      M
# 26047  26047         Kolkata, India 2014-06-22     Silver   Travel      F
# 26048  26048            Pune, India 2014-08-03  Signature   Travel      M
# 26050  26050          Kanpur, India 2014-09-14     Silver   Travel      M
#
#        Amount  WKD  total_no.of_transaction
# ...

# %%
y=cc.groupby(["City"])["Amount"].sum()

# %%
u=y.reset_index()

# %%
u
# Out:
#                  City  Amount
# 0     Achalpur, India  348051
# 1     Adilabad, India  585977
# 2    Adityapur, India  227532
# 3        Adoni, India  718170
# 4        Adoor, India  388364
# ..                ...     ...
# 802      Yevla, India  260537
# 803    Zaidpur, India   17420
# 804    Zamania, India  715258
# 805   Zirakpur, India   84925
# 806  Zunheboto, India  298567
#
# [807 rows x 2 columns]

# %%
u["total_no.of_transaction"]=7548

# %%
u
# Out:
#                  City  Amount  total_no.of_transaction
# 0     Achalpur, India  348051                     7548
# 1     Adilabad, India  585977                     7548
# 2    Adityapur, India  227532                     7548
# 3        Adoni, India  718170                     7548
# 4        Adoor, India  388364                     7548
# ..                ...     ...                      ...
# 802      Yevla, India  260537                     7548
# 803    Zaidpur, India   17420                     7548
# 804    Zamania, India  715258                     7548
# 805   Zirakpur, India   84925                     7548
# 806  Zunheboto, India  298567                     7548
#
# [807 rows x 3 columns]

# %%
u['Ratio']=(u["Amount"]/u["total_no.of_transaction"])

# %%
u
# Out:
#                  City  Amount  total_no.of_transaction      Ratio
# 0     Achalpur, India  348051                     7548  46.111685
# 1     Adilabad, India  585977                     7548  77.633413
# 2    Adityapur, India  227532                     7548  30.144674
# 3        Adoni, India  718170                     7548  95.147059
# 4        Adoor, India  388364                     7548  51.452570
# ..                ...     ...                      ...        ...
# 802      Yevla, India  260537                     7548  34.517356
# 803    Zaidpur, India   17420                     7548   2.307896
# 804    Zamania, India  715258                     7548  94.761261
# 805   Zirakpur, India   84925                     7548  11.251325
# 806  Zunheboto, India  298567                     7548  39.555776
#
# [807 rows x 4 columns]

# %%
u.nlargest(1,"Ratio")
# Out:
#                       City     Amount  total_no.of_transaction         Ratio
# 136  Greater Mumbai, India  172418991                     7548  22843.003577

# %% [markdown]
# #  3.Write a query to print the transaction details (all columns from the table) for each card type when it reaches a cumulative of 1000000 total spends (We should have 4 rows in the o/p one for each card type)

# %%
df["cumsum"]=df.groupby("Card Type")['Amount'].cumsum()

# %%
df.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount  \
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India  05-May-15       Gold    Bills      F  171574
#
#    cumsum
# 0   82475
# 1   32555
# 2  101738
# 3  123424
# 4  254049

# %%
a=df[(df["Card Type"]=="Silver")&(df["cumsum"]>=1000000)]

# %%
b=df[(df["Card Type"]=="Gold")&(df["cumsum"]>=1000000)]

# %%
c=df[(df["Card Type"]=="Platinum")&(df["cumsum"]>=1000000)]

# %%
d=df[(df["Card Type"]=="Signature")&(df["cumsum"]>=1000000)]

# %%
e=a.nsmallest(1,"cumsum")

# %%
f=b.nsmallest(1,"cumsum")

# %%
g=c.nsmallest(1,"cumsum")

# %%
h=d.nsmallest(1,"cumsum")

# %%
e
# Out:
#     index          City       Date Card Type Exp Type Gender  Amount   cumsum
# 25     25  Delhi, India  27-Sep-14    Silver    Bills      F  622170  1483205

# %%
f
# Out:
#     index                   City       Date Card Type Exp Type Gender  Amount  \
# 17     17  Greater Mumbai, India  30-Mar-15      Gold    Bills      F  986379
#
#      cumsum
# 17  1402904

# %%
g
# Out:
#     index                   City       Date Card Type Exp Type Gender  Amount  \
# 15     15  Greater Mumbai, India  28-Nov-14  Platinum    Bills      F  647116
#
#      cumsum
# 15  1178644

# %%
h
# Out:
#     index                   City       Date  Card Type Exp Type Gender  \
# 16     16  Greater Mumbai, India  14-Jun-14  Signature    Bills      F
#
#     Amount   cumsum
# 16  421878  1380531

# %%
sf=pd.concat([e,f,g,h],axis=0)

# %%
sf
# Out:
#     index                   City       Date  Card Type Exp Type Gender  \
# 25     25           Delhi, India  27-Sep-14     Silver    Bills      F
# 17     17  Greater Mumbai, India  30-Mar-15       Gold    Bills      F
# 15     15  Greater Mumbai, India  28-Nov-14   Platinum    Bills      F
# 16     16  Greater Mumbai, India  14-Jun-14  Signature    Bills      F
#
#     Amount   cumsum
# 25  622170  1483205
# 17  986379  1402904
# 15  647116  1178644
# 16  421878  1380531
