# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # SANITY NO 1

# %%
df=pd.read_csv("Credit Banking - 3.csv")

# %%
df.isnull().sum()
# Out:
# Credit_card          5
# Product_ID           0
# P_CATEGORY           0
# CONDTION             0
# Brand                0
# Price                0
# Selling_price        0
# Coupon_ID           20
# Date                 0
# Time                 0
# GTIN                 0
# MPN                  0
# Merchant_name        0
# M_ID                 0
# Payment Method       0
# Transaction ID       0
# Return_ind           0
# Return_date       8467
# dtype: int64

# %%
df['Credit_card'].fillna(9999,inplace=True)  ## sanity check 1

# %%
df.isnull().sum()
# Out:
# Credit_card          0
# Product_ID           0
# P_CATEGORY           0
# CONDTION             0
# Brand                0
# Price                0
# Selling_price        0
# Coupon_ID           20
# Date                 0
# Time                 0
# GTIN                 0
# MPN                  0
# Merchant_name        0
# M_ID                 0
# Payment Method       0
# Transaction ID       0
# Return_ind           0
# Return_date       8467
# dtype: int64

# %% [markdown]
# # SANITY NO 2

# %%
d=ts[ts['Price ']==ts['Selling_price']]

# %%
d.shape
# Out:
# (41, 19)

# %%
d[d['Coupon_ID'].notnull()]
# Out:
#      Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand  \
# 180       4852.0         765             DECOR          New  ZACKV
# 485       7979.0         534             SHOES          New  RKFCM
# 496       9305.0         838           BEDDING  Refurbished  CJUEU
# 511       3768.0         912        APPLIANCES          New  AVMAI
# 512       5008.0         535  KITCHEN & DINING          New  HLICV
# 524       7848.0         145          CLOTHING          New  ZVYTC
# 525       2024.0         111             GAMES          New  EITXF
# 526       3500.0         644             DECOR         Used  ZACKV
# 559       1174.0         931           BEDDING          New  CJUEU
# 846       7173.0         594          CLOTHING          New  ONKHS
# 847       9563.0         295         COMPUTERS         Used  DCJRW
# 882       2377.0         119         COMPUTERS          New  YXQFM
# 883       8299.0         635        APPLIANCES  Refurbished  AVMAI
# ...

# %%
d['Coupon_ID'].isnull().sum()
# Out:
# 0

# %%
d['Selling_price']=d['Selling_price'].str.replace('$','')

# %%
d['Selling_price']=d['Selling_price'].str.replace(',','')

# %%
d['Price ']=d['Price '].str.replace('$','')

# %%
d['Price ']=d['Price '].str.replace(' ','')

# %%
d['Price ']=d['Price '].str.replace(',','')

# %%
d['Selling_price']=d['Selling_price'].astype('float64')

# %%
d['Price ']=d['Price '].astype('float64')

# %%
d['Discount']=d['Price ']*(5/100)

# %%
d.insert(loc=8,column='Dis',value=d['Discount'])

# %%
d.drop(columns='Discount',inplace=True)

# %%
d.rename(columns={'Dis':'Discount'},inplace=True)

# %%
 d #### sanity check no.2
# Out:
#      Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand   Price   \
# 180       4852.0         765             DECOR          New  ZACKV  4557.18
# 485       7979.0         534             SHOES          New  RKFCM  1484.74
# 496       9305.0         838           BEDDING  Refurbished  CJUEU  1980.83
# 511       3768.0         912        APPLIANCES          New  AVMAI  3332.40
# 512       5008.0         535  KITCHEN & DINING          New  HLICV  4990.97
# 524       7848.0         145          CLOTHING          New  ZVYTC  3631.77
# 525       2024.0         111             GAMES          New  EITXF  4258.22
# 526       3500.0         644             DECOR         Used  ZACKV  4514.96
# 559       1174.0         931           BEDDING          New  CJUEU  4083.10
# 846       7173.0         594          CLOTHING          New  ONKHS  3715.86
# 847       9563.0         295         COMPUTERS         Used  DCJRW   622.19
# ...

# %% [markdown]
# # SANITY NO 3

# %%
q=df[~df.duplicated('Transaction ID')]

# %%
q.shape
# Out:
# (1419, 18)

# %%
r=ts[ts['Return_date'].notnull()]

# %%
r['Return_date']=pd.to_datetime(r['Return_date'])

# %%
q['Date']=pd.to_datetime(q['Date'])

# %%
qq=q[q['Return_date'].notnull()]

# %%
qq.shape
# Out:
# (871, 18)

# %%
rr=q[q['Return_date'].isna()]

# %%
rr.shape
# Out:
# (548, 18)

# %%
qq['op']=qq['Date']<qq['Return_date']

# %%
ss=pd.concat([qq,rr],axis=0)

# %%
tp=qq[qq['op']==True]

# %%
st=ss[ss['op']==True]

# %%
ts=pd.concat([st,rr],axis=0)

# %%
ts ##3
# Out:
#      Credit_card  Product_ID       P_CATEGORY     CONDTION  Brand      Price   \
# 9         5974.0         470          LUGGAGE         Used  TNVON  $4,783.25
# 28        7979.0         389         CLOTHING          New  GTFFL  $3,747.69
# 73        6502.0         662    BABY CLOTHING          New  CTAOI  $4,658.93
# 126       3199.0         484  OFFICE SUPPLIES         Used  WELZA  $2,205.71
# 147       2744.0         702       APPLIANCES  Refurbished  BUDLO  $4,042.54
# ..           ...         ...              ...          ...    ...         ...
# 828       9723.0         722      ELECTRONICS          New  OULOW  $3,469.59
# 829       4852.0         396    BABY CLOTHING  Refurbished  LATFL  $2,043.07
# 830       8639.0         552            SHOES          New  RKFCM  $1,257.44
# 831       1960.0         622        BABY TOYS          New  GOZLI  $2,603.49
# 832       2141.0         960          BEDDING          New  RKCPD  $2,882.99
#
# ...

# %% [markdown]
# # SANITY NO 4

# %%
a=ts[ts['Coupon_ID'].isna()]

# %%
a.shape
# Out:
# (20, 19)

# %%
a['selling_price']=a['Price ']

# %%
a[['Price ','selling_price']]
# Out:
#          Price  selling_price
# 377  $2,132.96     $2,132.96
# 445  $2,230.61     $2,230.61
# 505  $4,802.17     $4,802.17
# 5    $3,788.97     $3,788.97
# 23   $3,697.22     $3,697.22
# 37     $379.49       $379.49
# 61     $623.05       $623.05
# 85   $2,213.77     $2,213.77
# 105  $2,280.16     $2,280.16
# 134    $635.56       $635.56
# 166  $1,050.51     $1,050.51
# 201  $3,205.26     $3,205.26
# 237  $2,455.58     $2,455.58
# 272  $3,631.77     $3,631.77
# 298  $1,680.33     $1,680.33
# 323  $1,363.08     $1,363.08
# 353    $379.56       $379.56
# 399    $298.03       $298.03
# 417  $2,868.97     $2,868.97
# 418  $4,641.79     $4,641.79

# %%
a.drop(columns={'Selling_price'},inplace=True)

# %%
a.insert(loc=6,column='sel',value=a['selling_price'])

# %%
a.drop(columns='selling_price',inplace=True)

# %%
a.rename(columns={"sel":"Selling_price"},inplace=True)

# %%
a.insert(loc=7,column='Discount',value=0)

# %%
a['Discount'].replace(0,'-',inplace=True)

# %%
a     ### sanity check no 4
# Out:
#      Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand  \
# 377         4284         324       ELECTRONICS          New  AGSDS
# 445         7486         912             SHOES          New  VKKEA
# 505         7412         752   OFFICE SUPPLIES  Refurbished  EVWJY
# 5           4305         922           LUGGAGE          New  IWPJG
# 23          8532         849       ELECTRONICS  Refurbished  FMBZC
# 37          9275         775         BABY TOYS  Refurbished  CTAOI
# 61          6740         644          CLOTHING         Used  KXUWE
# 85          7412         827  KITCHEN & DINING          New  NSILF
# 105         7861         781             SHOES          New  VKKEA
# 134         6105         970           LUGGAGE  Refurbished  CENQJ
# 166         7001         816             DECOR          New  DGWZG
# 201         6105         986         COMPUTERS          New  YXQFM
# 237         7496         300         COMPUTERS         Used  YXQFM
# ...

# %% [markdown]
# # SANITY NO 5

# %%
df1=pd.read_csv('Credit Banking - 3part1.csv')

# %%
df1[df1['Age']<=18]
# Out:
#        C_ID                  Email       Name  Mobile_number Gender   Age  \
# 28   7173.0      marie@hotmail.com      MARIE   9.936858e+09      F  18.0
# 38   9063.0         alan@gmail.com       ALAN   9.983136e+09      F  15.0
# 48   3175.0  christine@hotmail.com  CHRISTINE   9.445081e+09      F  17.0
# 52   6143.0  rebecca@yahoomail.com    REBECCA   9.236432e+09      F  17.0
# 54   9587.0      karen@hotmail.com      KAREN   9.446573e+09      F  15.0
# 63   6071.0      craig@hotmail.com      CRAIG   8.946727e+09      M  15.0
# 76   7122.0  shirley@yahoomail.com    SHIRLEY   9.222061e+09      F  15.0
# 105  5157.0       lisa@hotmail.com       LISA   9.804086e+09      F  17.0
# 117  5974.0       judith@gmail.com     JUDITH   9.743625e+09      M  16.0
# 150  5069.0     philip@hotmail.com     PHILIP   9.155965e+09      F  15.0
# 159  8772.0        don@hotmail.com        DON   9.834172e+09      M  17.0
# 170  7856.0    julie@yahoomail.com      JULIE   9.840073e+09      M  17.0
# ...

# %%
df1['Age']=np.where(df1['Age']<=18,np.nan,df1['Age'])

# %%
df1[df1['Age']<=18]
# Out:
# Empty DataFrame
# Columns: [C_ID, Email, Name, Mobile_number, Gender, Age, City , State, Address]
# Index: []

# %%
q=df1['Age'].mean(skipna=True)

# %%
q
# Out:
# 60.65405405405406

# %%
df1['Age'].fillna(q,inplace=True)

# %%
df1[df1['Age']==q]
# Out:
#        C_ID                  Email       Name  Mobile_number Gender  \
# 28   7173.0      marie@hotmail.com      MARIE   9.936858e+09      F
# 38   9063.0         alan@gmail.com       ALAN   9.983136e+09      F
# 48   3175.0  christine@hotmail.com  CHRISTINE   9.445081e+09      F
# 52   6143.0  rebecca@yahoomail.com    REBECCA   9.236432e+09      F
# 54   9587.0      karen@hotmail.com      KAREN   9.446573e+09      F
# 63   6071.0      craig@hotmail.com      CRAIG   8.946727e+09      M
# 76   7122.0  shirley@yahoomail.com    SHIRLEY   9.222061e+09      F
# 105  5157.0       lisa@hotmail.com       LISA   9.804086e+09      F
# 117  5974.0       judith@gmail.com     JUDITH   9.743625e+09      M
# 150  5069.0     philip@hotmail.com     PHILIP   9.155965e+09      F
# 159  8772.0        don@hotmail.com        DON   9.834172e+09      M
# 170  7856.0    julie@yahoomail.com      JULIE   9.840073e+09      M
# 197  9532.0  katherine@hotmail.com  KATHERINE   9.033151e+09      M
# ...

# %%
df1 #### sanity check no 5
# Out:
#        C_ID                  Email       Name  Mobile_number Gender  \
# 0    3768.0    eddie@yahoomail.com      EDDIE   9.045258e+09      M
# 1    4852.0       rose@hotmail.com       ROSE   8.834789e+09      F
# 2    1174.0      amy@yahoomail.com        AMY   9.557690e+09      F
# 3    4807.0     clarence@gmail.com   CLARENCE   9.394398e+09      M
# 4    9131.0     johnny@hotmail.com     JOHNNY   9.976624e+09      F
# ..      ...                    ...        ...            ...    ...
# 197  9532.0  katherine@hotmail.com  KATHERINE   9.033151e+09      M
# 198     NaN                    NaN        NaN            NaN    NaN
# 199     NaN                    NaN        NaN            NaN    NaN
# 200     NaN                    NaN        NaN            NaN    NaN
# 201     NaN                    NaN        NaN            NaN    NaN
#
#            Age        City        State Address
# 0    83.000000   Louisville    Kentucky  Masked
# 1    87.000000  Kansas City    Missouri  Masked
# ...

# %% [markdown]
# # SANITY NO 6

# %%
df[df['Transaction ID'].duplicated()]
# Out:
#       Credit_card  Product_ID       P_CATEGORY     CONDTION  Brand  \
# 564        8639.0         138          LUGGAGE  Refurbished  CENQJ
# 623        9174.0         145          BEDDING          New  PIUEM
# 954        2637.0         931          LUGGAGE         Used  CENQJ
# 1043       2637.0         119  OFFICE SUPPLIES  Refurbished  EVWJY
# 1118       3040.0         324          LUGGAGE          New  IWPJG
# ...           ...         ...              ...          ...    ...
# 9994       8609.0         470       APPLIANCES          New  TTNTN
# 9995       9725.0         406         CLOTHING         Used  ONKHS
# 9996       1548.0         694      ELECTRONICS          New  AGSDS
# 9997       4878.0         552            SHOES          New  RKFCM
# 9998       8532.0         395  OFFICE SUPPLIES          New  WELZA
#
#           Price  Selling_price Coupon_ID        Date      Time     GTIN  \
# 564   $3,968.70     $3,956.70      EX642  01/08/2014  00:34:57  1042755
# ...

# %%
q=df[~df.duplicated('Transaction ID')]

# %%
ts ###sanity no 6
# Out:
#      Credit_card  Product_ID       P_CATEGORY     CONDTION  Brand      Price   \
# 9         5974.0         470          LUGGAGE         Used  TNVON  $4,783.25
# 28        7979.0         389         CLOTHING          New  GTFFL  $3,747.69
# 73        6502.0         662    BABY CLOTHING          New  CTAOI  $4,658.93
# 126       3199.0         484  OFFICE SUPPLIES         Used  WELZA  $2,205.71
# 147       2744.0         702       APPLIANCES  Refurbished  BUDLO  $4,042.54
# ..           ...         ...              ...          ...    ...         ...
# 828       9723.0         722      ELECTRONICS          New  OULOW  $3,469.59
# 829       4852.0         396    BABY CLOTHING  Refurbished  LATFL  $2,043.07
# 830       8639.0         552            SHOES          New  RKFCM  $1,257.44
# 831       1960.0         622        BABY TOYS          New  GOZLI  $2,603.49
# 832       2141.0         960          BEDDING          New  RKCPD  $2,882.99
#
# ...

# %% [markdown]
# # TASK 1

# %%
ts['Selling_price']=ts['Selling_price'].str.replace('$','')

# %%
ts['Selling_price']=ts['Selling_price'].str.replace(',','')

# %%
ts[ts['Selling_price']=='(1.87)']=np.nan

# %%
ts['Selling_price']=ts['Selling_price'].astype('float64')

# %%
ts['Selling_price'].dtypes
# Out:
# dtype('float64')

# %%
a=df1[(df1['Gender']=='M')]

# %%
a.shape
# Out:
# (93, 9)

# %%
def agee(val):
    if 17<val<=30:
        return 'Young Males'
    if 31<=val<=60:
        return 'Mid age Males'
    elif val>60:
        return 'Old Males'

# %%
a['Catg']=a['Age'].map(agee)

# %%
c=df1[(df1['Gender']=='F')]

# %%
c.shape
# Out:
# (105, 9)

# %%
def agee(val):
    if 17<val<=30:
        return 'Young Females'
    if 31<=val<=60:
        return 'Mid age Females'
    elif val>60:
        return 'Old Females'

# %%
c['category']=c['Age'].map(agee)

# %%
pdd=pd.concat([a,c],axis=0)

# %%
pdd.shape
# Out:
# (198, 11)

# %%
pdd['cattg']=pdd['Catg'].fillna('')+pdd['category'].fillna('')

# %%
pdd.isnull().sum()
# Out:
# C_ID               0
# Email              0
# Name               0
# Mobile_number      0
# Gender             0
# Age                0
# City               0
# State              0
# Address            0
# Catg             105
# category          93
# cattg              0
# dtype: int64

# %%
pdd.rename(columns={'cattg':'Age_catg'},inplace=True)

# %%
pdd.drop(columns={'Catg','category'},inplace=True)

# %%
pdd ### TASK 1
# Out:
#        C_ID                   Email      Name  Mobile_number Gender   Age  \
# 0    3768.0     eddie@yahoomail.com     EDDIE   9.045258e+09      M  83.0
# 3    4807.0      clarence@gmail.com  CLARENCE   9.394398e+09      M  37.0
# 5    3496.0  clifford@yahoomail.com  CLIFFORD   9.591889e+09      M  35.0
# 9    2637.0         ann@hotmail.com       ANN   9.506618e+09      M  65.0
# 11   9896.0      troy@yahoomail.com      TROY   9.197303e+09      M  39.0
# ..      ...                     ...       ...            ...    ...   ...
# 189  5229.0         helen@gmail.com     HELEN   9.064066e+09      F  60.0
# 191  7496.0       chris@hotmail.com     CHRIS   9.626130e+09      F  72.0
# 193  4575.0      tina@yahoomail.com      TINA   8.819353e+09      F  56.0
# 195  8609.0    jennifer@hotmail.com  JENNIFER   9.935043e+09      F  93.0
# 196  4542.0    michelle@hotmail.com  MICHELLE   9.730382e+09      F  60.0
#
#            City        State Address         Age_catg
# ...

# %% [markdown]
# # TASK 2

# %%
df2=pd.concat([ts,df1],axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1178 entries, 9 to 199
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Credit_card     1174 non-null   float64
#  1   Product_ID      1174 non-null   float64
#  2   P_CATEGORY      1174 non-null   object
#  3   CONDTION        1174 non-null   object
#  4   Brand           1174 non-null   object
#  5   Price           1174 non-null   object
#  6   Selling_price   1174 non-null   float64
#  7   Coupon_ID       1154 non-null   object
#  8   Date            1174 non-null   datetime64[ns]
#  9   Time            1174 non-null   object
#  10  GTIN            1174 non-null   float64
#  11  MPN             1174 non-null   float64
#  12  Merchant_name   1174 non-null   object
#  13  M_ID            1174 non-null   object
#  14  Payment Method  1174 non-null   object
#  15  Transaction ID  1174 non-null   float64
#  16  Return_ind      1174 non-null   float64
# ...

# %%
q=df2.groupby(['P_CATEGORY','State','Payment Method'])['Selling_price'].sum()

# %%
pq=q.reset_index()

# %%
pq.rename(columns={'Selling_price':'Total_spend'},inplace=True)

# %%
pq ####2
# Out:
#      P_CATEGORY          State          Payment Method  Total_spend
# 0    APPLIANCES     California             Credit card      4891.58
# 1    APPLIANCES     California  Mobile carrier Billing      4966.87
# 2    APPLIANCES     California            Prepaid card      3196.65
# 3    APPLIANCES  Massachusetts             Credit card      2028.24
# 4    APPLIANCES  Massachusetts            Prepaid card      2109.85
# ..          ...            ...                     ...          ...
# 133       SHOES          Texas             Credit card      4592.91
# 134       SHOES          Texas  Mobile carrier Billing      6232.90
# 135       SHOES          Texas            Prepaid card      2751.18
# 136       SHOES     Washington             Credit card      4284.02
# 137       SHOES     Washington  Mobile carrier Billing      2230.61
#
# [138 rows x 4 columns]

# %% [markdown]
# # TASK 3

# %%
df3=pd.concat([ts,pdd],axis=1)

# %%
df3.head(6)
# Out:
#      Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand  \
# 9         5974.0       470.0           LUGGAGE         Used  TNVON
# 28        7979.0       389.0          CLOTHING          New  GTFFL
# 73        6502.0       662.0     BABY CLOTHING          New  CTAOI
# 126       3199.0       484.0   OFFICE SUPPLIES         Used  WELZA
# 147       2744.0       702.0        APPLIANCES  Refurbished  BUDLO
# 164       1256.0       198.0  KITCHEN & DINING  Refurbished  RGMIK
#
#          Price   Selling_price Coupon_ID       Date      Time  ...    C_ID  \
# 9    $4,783.25         4764.25     ER876 2014-09-23  05:13:44  ...  2637.0
# 28   $3,747.69         3704.69     JL124 2014-01-17  13:11:00  ...  7173.0
# 73   $4,658.93         4609.93     JJ698 2014-03-10  21:17:54  ...  9950.0
# 126  $2,205.71         2171.71     GH952 2014-02-16  23:19:29  ...  7653.0
# 147  $4,042.54         4027.54     DK976 2014-04-02  22:33:44  ...  6825.0
# ...

# %%
q=df3.groupby(['Age_catg'])['Selling_price'].sum()

# %%
qq=q.reset_index()

# %%
qq.nlargest(5,'Selling_price')###3
# Out:
#           Age_catg  Selling_price
# 2      Old Females      138406.78
# 3        Old Males      135582.36
# 0  Mid age Females       89337.38
# 1    Mid age Males       58639.10
# 4    Young Females       35911.55

# %% [markdown]
# # TASK 4

# %%
r=ts[ts['Return_date'].notnull()]

# %%
r.isnull().sum()
# Out:
# Credit_card       0
# Product_ID        0
# P_CATEGORY        0
# CONDTION          0
# Brand             0
# Price             0
# Selling_price     0
# Coupon_ID         3
# Date              0
# Time              0
# GTIN              0
# MPN               0
# Merchant_name     0
# M_ID              0
# Payment Method    0
# Transaction ID    0
# Return_ind        0
# Return_date       0
# op                0
# dtype: int64

# %%
r
# Out:
#       Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand  \
# 9          5974.0       470.0           LUGGAGE         Used  TNVON
# 28         7979.0       389.0          CLOTHING          New  GTFFL
# 73         6502.0       662.0     BABY CLOTHING          New  CTAOI
# 126        3199.0       484.0   OFFICE SUPPLIES         Used  WELZA
# 147        2744.0       702.0        APPLIANCES  Refurbished  BUDLO
# 164        1256.0       198.0  KITCHEN & DINING  Refurbished  RGMIK
# 180        4852.0       765.0             DECOR          New  ZACKV
# 217        9210.0       931.0           LUGGAGE         Used  CENQJ
# 236        6214.0       722.0             GAMES          New  KJOGG
# 255        9086.0       544.0       ELECTRONICS         Used  FMBZC
# 285        4878.0       527.0  KITCHEN & DINING         Used  ZGHYW
# 308        2024.0       722.0             GAMES          New  KJOGG
# 327        9563.0       295.0         COMPUTERS         Used  DCJRW
# ...

# %%
r[r['Return_date'].notnull()]
# Out:
#       Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand  \
# 9          5974.0       470.0           LUGGAGE         Used  TNVON
# 28         7979.0       389.0          CLOTHING          New  GTFFL
# 73         6502.0       662.0     BABY CLOTHING          New  CTAOI
# 126        3199.0       484.0   OFFICE SUPPLIES         Used  WELZA
# 147        2744.0       702.0        APPLIANCES  Refurbished  BUDLO
# 164        1256.0       198.0  KITCHEN & DINING  Refurbished  RGMIK
# 180        4852.0       765.0             DECOR          New  ZACKV
# 217        9210.0       931.0           LUGGAGE         Used  CENQJ
# 236        6214.0       722.0             GAMES          New  KJOGG
# 255        9086.0       544.0       ELECTRONICS         Used  FMBZC
# 285        4878.0       527.0  KITCHEN & DINING         Used  ZGHYW
# 308        2024.0       722.0             GAMES          New  KJOGG
# 327        9563.0       295.0         COMPUTERS         Used  DCJRW
# ...

# %%
tt=pd.concat([r,pdd],axis=1)

# %%
p=tt[['P_CATEGORY','CONDTION','Return_date','Age_catg','State']]

# %%
p.columns
# Out:
# Index(['P_CATEGORY', 'CONDTION', 'Return_date', 'Age_catg', 'State'], dtype='object')

# %%
p.rename(columns={"Return_date":"Return_Date"},inplace=True)

# %%
a=r[['Brand','Price ','Return_date']]

# %%
pa=pd.concat([p,a],axis=1)

# %%
pa[pa['Return_date'].notnull()]
# Out:
#             P_CATEGORY     CONDTION Return_Date     Age_catg       State  \
# 9              LUGGAGE         Used  30-09-2014    Old Males    Kentucky
# 28            CLOTHING          New  24-01-2014  Old Females    Missouri
# 73       BABY CLOTHING          New  10-10-2014  Old Females     Arizona
# 126    OFFICE SUPPLIES         Used  23-02-2014  Young Males  California
# 147         APPLIANCES  Refurbished  11-02-2014    Old Males  California
# 164   KITCHEN & DINING  Refurbished  11-02-2014    Old Males    Illinois
# 180              DECOR          New  14-11-2014    Old Males    Kentucky
# 217            LUGGAGE         Used  04-02-2014          NaN         NaN
# 236              GAMES          New  09-02-2014          NaN         NaN
# 255        ELECTRONICS         Used  09-04-2014          NaN         NaN
# 285   KITCHEN & DINING         Used  06-05-2014          NaN         NaN
# 308              GAMES          New  24-01-2014          NaN         NaN
# ...

# %%
e=pa[pa['Return_date'].notnull()]

# %%
e.shape
# Out:
# (626, 8)

# %%
e.drop(columns='Return_Date',inplace=True)

# %%
e.drop(columns={'Price '},inplace=True)

# %%
e ### 4
# Out:
#             P_CATEGORY     CONDTION     Age_catg       State  Brand  \
# 9              LUGGAGE         Used    Old Males    Kentucky  TNVON
# 28            CLOTHING          New  Old Females    Missouri  GTFFL
# 73       BABY CLOTHING          New  Old Females     Arizona  CTAOI
# 126    OFFICE SUPPLIES         Used  Young Males  California  WELZA
# 147         APPLIANCES  Refurbished    Old Males  California  BUDLO
# 164   KITCHEN & DINING  Refurbished    Old Males    Illinois  RGMIK
# 180              DECOR          New    Old Males    Kentucky  ZACKV
# 217            LUGGAGE         Used          NaN         NaN  CENQJ
# 236              GAMES          New          NaN         NaN  KJOGG
# 255        ELECTRONICS         Used          NaN         NaN  FMBZC
# 285   KITCHEN & DINING         Used          NaN         NaN  ZGHYW
# 308              GAMES          New          NaN         NaN  KJOGG
# 327          COMPUTERS         Used          NaN         NaN  DCJRW
# ...

# %% [markdown]
# # TASK 5

# %%
ts['Time']=pd.to_datetime(ts['Time'])

# %%
ts['HR']=ts['Time'].dt.hour

# %%
ts['HR'].unique()
# Out:
# array([ 5., 13., 21., 23., 22.,  4.,  2., 11.,  1., 16., 14.,  3.,  7.,
#        17., 19.,  6.,  0.,  9., 10., 18., 12.,  8., 15., 20., nan])

# %%
ts['HR'].fillna(0,inplace=True)

# %%
ts['HR'].dtypes
# Out:
# dtype('float64')

# %%
ts['HR']=ts['HR'].astype('int64')

# %%
ts['HR'].value_counts()
# Out:
# 11    68
# 3     59
# 7     57
# 8     57
# 17    56
# 12    56
# 18    54
# 0     54
# 23    52
# 22    52
# 16    51
# 14    51
# 21    49
# 20    48
# 13    46
# 1     46
# 9     44
# 5     44
# 10    43
# 2     39
# 19    38
# 4     38
# 15    37
# 6     36
# Name: HR, dtype: int64

# %%
def tim(val):
    if 0<=val<=11:
        return 'Morning_customers'
    if 12<=val<=18:
        return 'Afternoon_customers'
    if 18<val<=23:
        return 'Night_customers'

# %%
ts['HR']=ts['HR'].map(tim)

# %%
ts['HR'].shape
# Out:
# (1175,)

# %%
ts['HR'].value_counts()
# Out:
# Morning_customers      585
# Afternoon_customers    351
# Night_customers        239
# Name: HR, dtype: int64

# %%
ts.rename(columns={'HR':'Cust_Profile'},inplace=True)

# %%
ts ### TASK 5
# Out:
#      Credit_card  Product_ID       P_CATEGORY     CONDTION  Brand      Price   \
# 9         5974.0       470.0          LUGGAGE         Used  TNVON  $4,783.25
# 28        7979.0       389.0         CLOTHING          New  GTFFL  $3,747.69
# 73        6502.0       662.0    BABY CLOTHING          New  CTAOI  $4,658.93
# 126       3199.0       484.0  OFFICE SUPPLIES         Used  WELZA  $2,205.71
# 147       2744.0       702.0       APPLIANCES  Refurbished  BUDLO  $4,042.54
# ..           ...         ...              ...          ...    ...         ...
# 828       9723.0       722.0      ELECTRONICS          New  OULOW  $3,469.59
# 829       4852.0       396.0    BABY CLOTHING  Refurbished  LATFL  $2,043.07
# 830       8639.0       552.0            SHOES          New  RKFCM  $1,257.44
# 831       1960.0       622.0        BABY TOYS          New  GOZLI  $2,603.49
# 832       2141.0       960.0          BEDDING          New  RKCPD  $2,882.99
#
# ...

# %%
ts.drop(columns={'Time','GTIN','MPN','Merchant_name','M_ID','Return_ind'},inplace=True)

# %% [markdown]
# # TASK 6

# %%
o=d.groupby(['Payment Method'])['Discount'].sum().nlargest(1)

# %%
qu=o.reset_index()

# %%
qu  ### TASK
# Out:
#            Payment Method   Discount
# 0  Mobile carrier Billing  2619.0285

# %% [markdown]
# # TASK 7

# %%
ts['Price ']=ts['Price '].str.replace('$','')

# %%
ts['Price ']=ts['Price '].str.replace(',','')

# %%
ts['Price ']=ts['Price '].str.replace(' ','')

# %%
ts['Price ']=ts['Price '].astype('float64')

# %%
def price(val):
    if  val>3000 :
        return 'high_value_items'
    elif val <= 3000:
        return 'low_value_items'

# %%
ts['Price_val']=ts['Price '].map(price)

# %%
ts['Price_val'].value_counts()  ####7
# Out:
# low_value_items     640
# high_value_items    534
# Name: Price_val, dtype: int64

# %%
## NO OF ORDERS IS HIGH FOR LOW_VALUE_ITEMS

# %% [markdown]
# # TASK 8

# %%
import matplotlib.pyplot as plt

# %%
d
# Out:
#      Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand   Price   \
# 180       4852.0         765             DECOR          New  ZACKV  4557.18
# 485       7979.0         534             SHOES          New  RKFCM  1484.74
# 496       9305.0         838           BEDDING  Refurbished  CJUEU  1980.83
# 511       3768.0         912        APPLIANCES          New  AVMAI  3332.40
# 512       5008.0         535  KITCHEN & DINING          New  HLICV  4990.97
# 524       7848.0         145          CLOTHING          New  ZVYTC  3631.77
# 525       2024.0         111             GAMES          New  EITXF  4258.22
# 526       3500.0         644             DECOR         Used  ZACKV  4514.96
# 559       1174.0         931           BEDDING          New  CJUEU  4083.10
# 846       7173.0         594          CLOTHING          New  ONKHS  3715.86
# 847       9563.0         295         COMPUTERS         Used  DCJRW   622.19
# ...

# %%
d['Count']=np.arange(d.shape[0])

# %%
d
# Out:
#      Credit_card  Product_ID        P_CATEGORY     CONDTION  Brand   Price   \
# 180       4852.0         765             DECOR          New  ZACKV  4557.18
# 485       7979.0         534             SHOES          New  RKFCM  1484.74
# 496       9305.0         838           BEDDING  Refurbished  CJUEU  1980.83
# 511       3768.0         912        APPLIANCES          New  AVMAI  3332.40
# 512       5008.0         535  KITCHEN & DINING          New  HLICV  4990.97
# 524       7848.0         145          CLOTHING          New  ZVYTC  3631.77
# 525       2024.0         111             GAMES          New  EITXF  4258.22
# 526       3500.0         644             DECOR         Used  ZACKV  4514.96
# 559       1174.0         931           BEDDING          New  CJUEU  4083.10
# 846       7173.0         594          CLOTHING          New  ONKHS  3715.86
# 847       9563.0         295         COMPUTERS         Used  DCJRW   622.19
# ...

# %%
x=d['Count']
y=d['Transaction ID']

# %%
plt.scatter(x,y,c='r')
plt.xlabel('No.of orders')
plt.ylabel('Discount')
plt.title('No.of orders vs Discount')
plt.show()

# %%
## As there is a random distribution between the axes so, we can say that there may be or not discount will increase with no.of orders.
